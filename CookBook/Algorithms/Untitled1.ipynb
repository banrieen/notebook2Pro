# %% [markdown]
# ## 1. 两数之和
# 给定一个整数数组 nums 和一个目标值 target，请你在该数组中找出和为目标值的那 两个 整数，并返回他们的数组下标。
#
# 你可以假设每种输入只会对应一个答案。但是，你不能重复利用这个数组中同样的元素。
#
# 示例:
#
# 给定 nums = [2, 7, 11, 15], target = 9
#
# 因为 nums[0] + nums[1] = 2 + 7 = 9
# 所以返回 [0, 1]
#
# 来源：力扣（LeetCode）
# 链接：https://leetcode-cn.com/problems/two-sum

# %%
# 枚举解法
class Solution:
    def twoSum(self, nums: List[int], target: int) -> List[int]:
        length = len(nums)
        if length < 2:
            return None
        for i in range(0, length):
            for j in range(i,length):
                if nums[i] + nums[j] == target and i != j:
                    return [i ,j]
                else:
                    continue
        return None

# %%
"""
# 借助于 hash 表结构，｛value:index｝一次遍历
# Testcase:

>>> Solution().twoSum([2,7,11,15],9)
[0,1]

"""

class Solution:
    def twoSum(self, nums, target):
        length = len(nums)
        if length < 2:
            return None
        rst = {}
        temp = 0
        for i in range(0, length):
            import pdb
            pdb.set_trace()
            rst[nums[i]] = i
            temp = target - nums[i]
            print(f"")
            if rst.get(temp) and rst.get(temp) != i:
                return [rst.get(temp),i]
            else:
                continue
        return None

    if __name__ == "__main__":
#         import doctest
#         doctest.testmod(verbose=True)
        Solution().twoSum([2,7,11,15],9)
# Out:
# > <ipython-input-3-d1b4ffbfd930>(20)twoSum()
# -> rst[nums[i]] = i
# (Pdb) ll
#  11  	    def twoSum(self, nums, target):
#  12  	        length = len(nums)
#  13  	        if length < 2:
#  14  	            return None
#  15  	        rst = {}
#  16  	        temp = 0
#  17  	        for i in range(0, length):
#  18  	            import pdb
#  19  	            pdb.set_trace()
#  20  ->	            rst[nums[i]] = i
#  21  	            temp = target - nums[i]
#  22  	            print(f"")
#  23  	            if rst.get(temp) and rst.get(temp) != i:
#  24  	                return [rst.get(temp),i]
#  25  	            else:
#  26  	                continue
#  27  	        return None
# (Pdb) a
# self = <__main__.Solution object at 0x7f35810b1208>
# nums = [2, 7, 11, 15]
# target = 9
# (Pdb) n
# > <ipython-input-3-d1b4ffbfd930>(21)twoSum()
# -> temp = target - nums[i]
# (Pdb) a
# self = <__main__.Solution object at 0x7f35810b1208>
# nums = [2, 7, 11, 15]
# target = 9
# (Pdb) pp temp,nums[i]
# (0, 2)
# (Pdb) n
# > <ipython-input-3-d1b4ffbfd930>(22)twoSum()
# -> print(f"")
# (Pdb) l
#  17  	        for i in range(0, length):
#  18  	            import pdb
#  19  	            pdb.set_trace()
#  20  	            rst[nums[i]] = i
#  21  	            temp = target - nums[i]
#  22  ->	            print(f"")
#  23  	            if rst.get(temp) and rst.get(temp) != i:
#  24  	                return [rst.get(temp),i]
#  25  	            else:
#  26  	                continue
#  27  	        return None
# (Pdb) pp temp , target , nums[i]
# (7, 9, 2)
# (Pdb) pp rst.get(temp)
# None
# (Pdb) n
#
# > <ipython-input-3-d1b4ffbfd930>(23)twoSum()
# -> if rst.get(temp) and rst.get(temp) != i:
# (Pdb) n
# > <ipython-input-3-d1b4ffbfd930>(17)twoSum()
# -> for i in range(0, length):
# (Pdb) n
# > <ipython-input-3-d1b4ffbfd930>(18)twoSum()
# -> import pdb
# (Pdb) n
# > <ipython-input-3-d1b4ffbfd930>(19)twoSum()
# -> pdb.set_trace()
# (Pdb) n
# > <ipython-input-3-d1b4ffbfd930>(20)twoSum()
# -> rst[nums[i]] = i
# (Pdb) pp rst
# {2: 0}
# (Pdb) n
# > <ipython-input-3-d1b4ffbfd930>(21)twoSum()
# -> temp = target - nums[i]
# (Pdb) pp rst
# {2: 0, 7: 1}
# (Pdb) n
# > <ipython-input-3-d1b4ffbfd930>(22)twoSum()
# -> print(f"")
# (Pdb) pp temp ,nums[i],i
# (2, 7, 1)
